# %%
# %run gpuinfo.py
# %run ./scripts/fixrand.py

# %%
# %run train.py -t "D:\\DiplomDataset\\train_config.yaml" -i "D:\\DiplomDataset\\inference_config.yaml"
# %run train.py -t "D:\\DiplomDataset\\train_config.yaml" -i "D:\\DiplomDataset\\inference_config.yaml"
# %run train.py -t "D:\\DiplomDataset\\train_config.yaml" -i "D:\\DiplomDataset\\inference_config.yaml"
# %run train.py -t "D:\\DiplomDataset\\train_config.yaml" -i "D:\\DiplomDataset\\inference_config.yaml"

# %%
# %run inference.py -c "D:\\DiplomDataset\\inference_config.yaml"

# %%
# import albumentations as A

# transforms = A.Compose([
#     A.RandomShadow(p=0.2),
#     A.RandomFog(p=0.2),
#     A.RandomGamma(p=0.2),
#     A.GaussianBlur(p=0.2),
#     A.GaussNoise((.1, .25), p=0.2),
#     A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), p=0.2),
#     # A.ToTensor3D()
# ]) 


# def get_classes(xml_file: Path) -> list[str]:
#     """Получение уникальных классов из файла аннотаций""" 
#     out = set()
#     if (root := get_xml_root(xml_file)) is not None:
#         out = { box.get("label") for box in root.iter("box") } 
#     if not out:
#         print(Fore.YELLOW + "Классов не найдено.")
#     return sorted(filter(None, out))
